# %%
import sys
import types
import pandas as pd 
from botocore.client import Config
import ibm_boto3


import numpy as np
import pandas as pd
from pandas import Series, DataFrame, Index
from IPython.display import Image

def __iter__(self): return 0

import pandas as pd
import numpy as np 

class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
from ibmdbpy.base import IdaDataBase

# %%
# The code was removed by Watson Studio for sharing.

# %%
import ibmdbpy
from ibmdbpy import IdaDataBase
idadb = idadb = IdaDataBase(dsn="DASHDB;Database=BLUDB;Hostname=" + credentials_1["host"] + ";PROTOCOL=TCPIP;UID=" + credentials_1["username"] + ";PWD=" + credentials_1["password"])

# %%
from ibmdbpy import IdaDataFrame

df_promotion_summaryx = idadb.ida_query("SELECT T0.PROMO_ID AS PROMO_ID,T0.PROMO_NAME AS PROMO_NAME,T0.PRICE_POINT AS PRICE_POINT,T0.RETAILER_NAME AS RETAILER_NAME,T0.RETAILER_STORE_ID AS RETAILER_STORE_ID,T0.PRODUCT_GROUP_ID AS PRODUCT_GROUP_ID,T0.PRODUCT_UNIT_UPC AS PRODUCT_UNIT_UPC,T0.PRODUCT_BRAND AS PRODUCT_BRAND,T0.PRODUCT_BRAND_CATEGORY_DESC AS PRODUCT_BRAND_CATEGORY_DESC,T0.PRODUCT_UNIT_DESCRIPTION AS PRODUCT_UNIT_DESCRIPTION,T0.PRICE AS PRICE,T0.TPP_TYPE AS TPP_TYPE,T0.TPP_START AS TPP_START,T0.TPP_END AS TPP_END,T0.PRODUCT_UNITS_PER_CASE AS PRODUCT_UNITS_PER_CASE,T0.PRODUCT_CPG_COGS_PRICE AS PRODUCT_CPG_COGS_PRICE,T0.SIZE AS SIZE,T0.CASES AS CASES,T0.GROUP AS GROUP,T0.UNITS AS UNITS,T0.P_UNITS AS P_UNITS,T0.PRODUCT AS PRODUCT FROM (SELECT T0.PROMO_ID AS PROMO_ID,T0.PROMO_NAME AS PROMO_NAME,T0.PRICE_POINT AS PRICE_POINT,T0.RETAILER_NAME AS RETAILER_NAME,T0.RETAILER_STORE_ID AS RETAILER_STORE_ID,T0.PRODUCT_GROUP_ID AS PRODUCT_GROUP_ID,T0.PRODUCT_UNIT_UPC AS PRODUCT_UNIT_UPC,T0.PRODUCT_BRAND AS PRODUCT_BRAND,T0.PRODUCT_BRAND_CATEGORY_DESC AS PRODUCT_BRAND_CATEGORY_DESC,T0.PRODUCT_UNIT_DESCRIPTION AS PRODUCT_UNIT_DESCRIPTION,T0.PRICE AS PRICE,T0.TPP_TYPE AS TPP_TYPE,T0.TPP_START AS TPP_START,T0.TPP_END AS TPP_END,T0.PRODUCT_UNITS_PER_CASE AS PRODUCT_UNITS_PER_CASE,T0.PRODUCT_CPG_COGS_PRICE AS PRODUCT_CPG_COGS_PRICE,T0.SIZE AS SIZE,T0.CASES AS CASES,T0.GROUP AS GROUP,T0.UNITS AS UNITS,T0.P_UNITS AS P_UNITS,'CEREAL' AS PRODUCT,'0' AS APPENDXYZ FROM DASH10112.CEREAL_FINAL_PRODUCTION T0 UNION ALL SELECT T0.PROMO_ID AS PROMO_ID,T0.PROMO_NAME AS PROMO_NAME,T0.PRICE_POINT AS PRICE_POINT,T0.RETAILER_NAME AS RETAILER_NAME,T0.RETAILER_STORE_ID AS RETAILER_STORE_ID,T0.PRODUCT_GROUP_ID AS PRODUCT_GROUP_ID,T0.PRODUCT_UNIT_UPC AS PRODUCT_UNIT_UPC,T0.PRODUCT_BRAND AS PRODUCT_BRAND,T0.PRODUCT_BRAND_CATEGORY_DESC AS PRODUCT_BRAND_CATEGORY_DESC,T0.PRODUCT_UNIT_DESCRIPTION AS PRODUCT_UNIT_DESCRIPTION,T0.PRICE AS PRICE,T0.TPP_TYPE AS TPP_TYPE,T0.TPP_START AS TPP_START,T0.TPP_END AS TPP_END,T0.PRODUCT_UNITS_PER_CASE AS PRODUCT_UNITS_PER_CASE,T0.PRODUCT_CPG_COGS_PRICE AS PRODUCT_CPG_COGS_PRICE,T0.SIZE AS SIZE,T0.CASES AS CASES,T0.GROUP AS GROUP,T0.UNITS AS UNITS,T0.P_UNITS AS P_UNITS,'YOGURT' AS PRODUCT,'1' AS APPENDXYZ FROM DASH10112.YOGURT_FINAL_PRODUCTION T0 UNION ALL SELECT T0.PROMO_ID AS PROMO_ID,T0.PROMO_NAME AS PROMO_NAME,T0.PRICE_POINT AS PRICE_POINT,T0.RETAILER_NAME AS RETAILER_NAME,T0.RETAILER_STORE_ID AS RETAILER_STORE_ID,T0.PRODUCT_GROUP_ID AS PRODUCT_GROUP_ID,T0.PRODUCT_UNIT_UPC AS PRODUCT_UNIT_UPC,T0.PRODUCT_BRAND AS PRODUCT_BRAND,T0.PRODUCT_BRAND_CATEGORY_DESC AS PRODUCT_BRAND_CATEGORY_DESC,T0.PRODUCT_UNIT_DESCRIPTION AS PRODUCT_UNIT_DESCRIPTION,T0.PRICE AS PRICE,T0.TPP_TYPE AS TPP_TYPE,T0.TPP_START AS TPP_START,T0.TPP_END AS TPP_END,T0.PRODUCT_UNITS_PER_CASE AS PRODUCT_UNITS_PER_CASE,T0.PRODUCT_CPG_COGS_PRICE AS PRODUCT_CPG_COGS_PRICE,T0.SIZE AS SIZE,T0.CASES AS CASES,T0.GROUP AS GROUP,T0.UNITS AS UNITS,T0.P_UNITS AS P_UNITS,'TRAIL_MIX' AS PRODUCT,'2' AS APPENDXYZ FROM DASH10112.TRAIL_MIX_FINAL_PRODUCTION T0 UNION ALL SELECT T0.PROMO_ID AS PROMO_ID,T0.PROMO_NAME AS PROMO_NAME,T0.PRICE_POINT AS PRICE_POINT,T0.RETAILER_NAME AS RETAILER_NAME,T0.RETAILER_STORE_ID AS RETAILER_STORE_ID,T0.PRODUCT_GROUP_ID AS PRODUCT_GROUP_ID,T0.PRODUCT_UNIT_UPC AS PRODUCT_UNIT_UPC,T0.PRODUCT_BRAND AS PRODUCT_BRAND,T0.PRODUCT_BRAND_CATEGORY_DESC AS PRODUCT_BRAND_CATEGORY_DESC,T0.PRODUCT_UNIT_DESCRIPTION AS PRODUCT_UNIT_DESCRIPTION,T0.PRICE AS PRICE,T0.TPP_TYPE AS TPP_TYPE,T0.TPP_START AS TPP_START,T0.TPP_END AS TPP_END,T0.PRODUCT_UNITS_PER_CASE AS PRODUCT_UNITS_PER_CASE,T0.PRODUCT_CPG_COGS_PRICE AS PRODUCT_CPG_COGS_PRICE,T0.SIZE AS SIZE,T0.CASES AS CASES,T0.GROUP AS GROUP,T0.UNITS AS UNITS,T0.P_UNITS AS P_UNITS,'ICE CREAM' AS PRODUCT,'3' AS APPENDXYZ FROM DASH10112.ICE_CREAM_FINAL T0 UNION ALL SELECT T0.PROMO_ID AS PROMO_ID,T0.PROMO_NAME AS PROMO_NAME,T0.PRICE_POINT AS PRICE_POINT,T0.RETAILER_NAME AS RETAILER_NAME,T0.RETAILER_STORE_ID AS RETAILER_STORE_ID,T0.PRODUCT_GROUP_ID AS PRODUCT_GROUP_ID,T0.PRODUCT_UNIT_UPC AS PRODUCT_UNIT_UPC,T0.PRODUCT_BRAND AS PRODUCT_BRAND,T0.PRODUCT_BRAND_CATEGORY_DESC AS PRODUCT_BRAND_CATEGORY_DESC,T0.PRODUCT_UNIT_DESCRIPTION AS PRODUCT_UNIT_DESCRIPTION,T0.PRICE AS PRICE,T0.TPP_TYPE AS TPP_TYPE,T0.TPP_START AS TPP_START,T0.TPP_END AS TPP_END,T0.PRODUCT_UNITS_PER_CASE AS PRODUCT_UNITS_PER_CASE,T0.PRODUCT_CPG_COGS_PRICE AS PRODUCT_CPG_COGS_PRICE,T0.SIZE AS SIZE,T0.CASES AS CASES,T0.GROUP AS GROUP,T0.UNITS AS UNITS,T0.P_UNITS AS P_UNITS,'CLEANERS' AS PRODUCT,'4' AS APPENDXYZ FROM DASH10112.CLEANERS_FINAL_PRODUCTION T0 UNION ALL SELECT T0.PROMO_ID AS PROMO_ID,T0.PROMO_NAME AS PROMO_NAME,T0.PRICE_POINT AS PRICE_POINT,T0.RETAILER_NAME AS RETAILER_NAME,T0.RETAILER_STORE_ID AS RETAILER_STORE_ID,T0.PRODUCT_GROUP_ID AS PRODUCT_GROUP_ID,T0.PRODUCT_UNIT_UPC AS PRODUCT_UNIT_UPC,T0.PRODUCT_BRAND AS PRODUCT_BRAND,T0.PRODUCT_BRAND_CATEGORY_DESC AS PRODUCT_BRAND_CATEGORY_DESC,T0.PRODUCT_UNIT_DESCRIPTION AS PRODUCT_UNIT_DESCRIPTION,T0.PRICE AS PRICE,T0.TPP_TYPE AS TPP_TYPE,T0.TPP_START AS TPP_START,T0.TPP_END AS TPP_END,T0.PRODUCT_UNITS_PER_CASE AS PRODUCT_UNITS_PER_CASE,T0.PRODUCT_CPG_COGS_PRICE AS PRODUCT_CPG_COGS_PRICE,T0.SIZE AS SIZE,T0.CASES AS CASES,T0.GROUP AS GROUP,T0.UNITS AS UNITS,T0.P_UNITS AS P_UNITS,'VEGETABLES' AS PRODUCT,'5' AS APPENDXYZ FROM DASH10112.VEGETABLES_FINAL_PRODUCTION T0) T0 WHERE (((T0.PROMO_ID = 'Brandega-21621') OR (T0.PROMO_ID = 'Brandega-48335')) OR (T0.PROMO_ID = 'Brandega-53999')) ORDER BY 10 ASC,22 ASC,1 ASC,5 ASC,8 ASC")

# %%
df_promotion_summary=df_promotion_summaryx
df_promotion_summary.head()
df_promotion_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378900 entries, 0 to 378899
# Data columns (total 22 columns):
# promo_id                       378900 non-null object
# promo_name                     378900 non-null object
# price_point                    378900 non-null object
# retailer_name                  378900 non-null object
# retailer_store_id              378900 non-null object
# product_group_id               378900 non-null object
# product_unit_upc               378900 non-null object
# product_brand                  378900 non-null object
# product_brand_category_desc    378900 non-null object
# product_unit_description       378900 non-null object
# price                          378900 non-null float64
# tpp_type                       378900 non-null object
# tpp_start                      378900 non-null object
# tpp_end                        378900 non-null object
# product_units_per_case         378900 non-null float64
# ...

# %%
import random
df_promotion_summary['randNumCol'] = np.random.choice([1, -1], df_promotion_summary.shape[0])

# %%
import random as random

df_promotion_summary['RANDOM_DUDE'] =(np.random.randint(-100, 100, df_promotion_summary.shape[0]))/1000
#df_promotion_summary['units']=df_promotion_summary['units']*(1+df_promotion_summary['randNumCol']*df_promotion_summary['RANDOM_DUDE'])

df_promotion_summary.describe()
# Out:
#                price  product_units_per_case  product_cpg_cogs_price  \
# count  378900.000000           378900.000000           378900.000000
# mean        5.569782               20.788889                4.415889
# std         2.716081               12.949058                2.094737
# min         1.459496                3.000000                1.520000
# 25%         3.744048               12.000000                3.490000
# 50%         5.000069               21.000000                4.085000
# 75%         7.340052               25.000000                6.190000
# max        21.015720               40.000000               12.520000
#
#                 size          cases          units        p_units  \
# count  378900.000000  378900.000000  378900.000000  378900.000000
# mean       20.322222       3.133333      43.616667     370.230772
# std        25.888933       2.993330      22.597049     957.384591
# min        -8.000000       1.000000       6.000000       0.000000
# ...

# %%
df_promotion_summary=df_promotion_summary.drop(['RANDOM_DUDE', 'randNumCol'], axis=1)

# %%
sale=df_promotion_summary[df_promotion_summary['group'] == 'ONSALE']
nosale=df_promotion_summary[df_promotion_summary['group'] == 'NOTONSALE']

# %%
nosale.describe()
# Out:
#                price  product_units_per_case  product_cpg_cogs_price  \
# count  189450.000000           189450.000000           189450.000000
# mean        5.805004               20.788889                4.415889
# std         2.844451               12.949075                2.094740
# min         1.459496                3.000000                1.520000
# 25%         3.831461               12.000000                3.490000
# 50%         5.171553               21.000000                4.085000
# 75%         7.719336               25.000000                6.190000
# max        21.015720               40.000000               12.520000
#
#                 size          cases          units        p_units
# count  189450.000000  189450.000000  189450.000000  189450.000000
# mean       20.322222       1.977778      28.422222     383.183410
# std        25.888967       1.483077      10.369832    1022.153408
# min        -8.000000       1.000000       6.000000       0.000000
# ...

# %%
print(sale.shape)
print(nosale.shape)
# Out:
# (189450, 22)
# (189450, 22)

# %%
sale = sale[['promo_id',
 'retailer_store_id',
 'product_group_id',
 'product_unit_upc',
 'product',
 'price','p_units','price_point']]

sale=sale.rename(index=str, columns={"price": "sale_price", "p_units": "sale_units"})

sale.head()
# Out:
#          promo_id retailer_store_id product_group_id product_unit_upc  \
# 0  Brandega-53999   12345-10024-126     D-H-C-AP-10       33488-14010
# 1  Brandega-53999   12345-10024-126     D-H-C-AP-10       33488-14010
# 2  Brandega-53999   12345-10024-126     D-H-C-AP-10       33488-14010
# 4  Brandega-53999   12345-10024-126     D-H-C-AP-10       33488-14010
# 6  Brandega-53999   12345-10024-126     D-H-C-AP-10       33488-14010
#
#     product  sale_price  sale_units price_point
# 0  CLEANERS     3.63902   22.652796           W
# 1  CLEANERS     3.85308   22.412617           Y
# 2  CLEANERS     3.42496   22.892975           Z
# 4  CLEANERS     4.06714   22.172438           V
# 6  CLEANERS     4.28120   21.932258           X

# %%
nosale = nosale[['promo_id',
 'retailer_store_id',
 'product_group_id',
 'product_unit_upc',
 'product',
 'price','units','price_point']]

nosale=nosale.rename(index=str, columns={"price": "standard_price","units":"standard_units"})

nosale.head()
# Out:
#          promo_id retailer_store_id product_group_id product_unit_upc  \
# 3  Brandega-53999   12345-10024-126     D-H-C-AP-10       33488-14010
# 5  Brandega-53999   12345-10024-126     D-H-C-AP-10       33488-14010
# 7  Brandega-53999   12345-10024-126     D-H-C-AP-10       33488-14010
# 8  Brandega-53999   12345-10024-126     D-H-C-AP-10       33488-14010
# 9  Brandega-53999   12345-10024-126     D-H-C-AP-10       33488-14010
#
#     product  standard_price  standard_units price_point
# 3  CLEANERS        5.087506            12.0           V
# 5  CLEANERS        4.819743            12.0           Y
# 7  CLEANERS        4.551979            12.0           W
# 8  CLEANERS        4.284216            12.0           Z
# 9  CLEANERS        5.355270            12.0           X

# %%
sale_nosale =sale.merge(nosale, on=['promo_id','retailer_store_id','product_group_id','product_unit_upc','product','price_point'], how='inner')
sale_nosale.head()
sale_nosale.shape
# Out:
# (189450, 10)

# %%
df_promotion_summary=df_promotion_summary[df_promotion_summary['group'] == 'ONSALE']

# %%
df_promotion_summary=df_promotion_summary.drop(['price','group','cases'], axis=1)

# %%
df_promotion_summary =df_promotion_summary.merge(sale_nosale, on=['promo_id','retailer_store_id','product_group_id','product_unit_upc','product','price_point'], how='inner')
df_promotion_summary
# Out:
#               promo_id         promo_name price_point      retailer_name  \
# 0       Brandega-53999  Spring into Clean           W           Botann's
# 1       Brandega-53999  Spring into Clean           Y           Botann's
# 2       Brandega-53999  Spring into Clean           Z           Botann's
# 3       Brandega-53999  Spring into Clean           V           Botann's
# 4       Brandega-53999  Spring into Clean           X           Botann's
# 5       Brandega-53999  Spring into Clean           Z           Botann's
# 6       Brandega-53999  Spring into Clean           Y           Botann's
# 7       Brandega-53999  Spring into Clean           X           Botann's
# 8       Brandega-53999  Spring into Clean           W           Botann's
# 9       Brandega-53999  Spring into Clean           V           Botann's
# 10      Brandega-53999  Spring into Clean           V           Botann's
# 11      Brandega-53999  Spring into Clean           Y           Botann's
# ...

# %%
zzz=df_promotion_summary.drop(['standard_price'], axis=1)

conditions = [
    (zzz['promo_id'] == 'Brandega-53999'),
    (zzz['promo_id'] == 'Brandega-48335'),
    (zzz['promo_id'] == 'Brandega-21621')]
choices = [7.41, 4.61, 6.89]
zzz['standard_price'] = np.select(conditions, choices, default=0.02)

# %%
df_promotion_summary=zzz

# %%
df_promotion_summary['SALE_REVENUE']=df_promotion_summary['sale_units']*df_promotion_summary['sale_price']
df_promotion_summary['SALE_COST']=df_promotion_summary['sale_units']*df_promotion_summary['product_cpg_cogs_price']
df_promotion_summary['SALE_PROFIT']=df_promotion_summary['SALE_REVENUE']-df_promotion_summary['SALE_COST']
df_promotion_summary.head(10)
# Out:
#          promo_id         promo_name price_point retailer_name  \
# 0  Brandega-53999  Spring into Clean           W      Botann's
# 1  Brandega-53999  Spring into Clean           Y      Botann's
# 2  Brandega-53999  Spring into Clean           Z      Botann's
# 3  Brandega-53999  Spring into Clean           V      Botann's
# 4  Brandega-53999  Spring into Clean           X      Botann's
# 5  Brandega-53999  Spring into Clean           Z      Botann's
# 6  Brandega-53999  Spring into Clean           Y      Botann's
# 7  Brandega-53999  Spring into Clean           X      Botann's
# 8  Brandega-53999  Spring into Clean           W      Botann's
# 9  Brandega-53999  Spring into Clean           V      Botann's
#
#   retailer_store_id product_group_id product_unit_upc product_brand  \
# 0   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 1   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# ...

# %%
df_promotion_summary['STANDARD_REVENUE']=df_promotion_summary['standard_units']*df_promotion_summary['standard_price']
df_promotion_summary['STANDARD_COST']=df_promotion_summary['standard_units']*df_promotion_summary['product_cpg_cogs_price']
df_promotion_summary['STANDARD_PROFIT']=df_promotion_summary['STANDARD_REVENUE']-df_promotion_summary['STANDARD_COST']
df_promotion_summary.head()
# Out:
#          promo_id         promo_name price_point retailer_name  \
# 0  Brandega-53999  Spring into Clean           W      Botann's
# 1  Brandega-53999  Spring into Clean           Y      Botann's
# 2  Brandega-53999  Spring into Clean           Z      Botann's
# 3  Brandega-53999  Spring into Clean           V      Botann's
# 4  Brandega-53999  Spring into Clean           X      Botann's
#
#   retailer_store_id product_group_id product_unit_upc product_brand  \
# 0   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 1   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 2   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 3   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 4   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
#
#            product_brand_category_desc      product_unit_description  \
# 0  Dottie's Cleaners All Purpose 10 oz  Dottie's Air Freshener 10 oz
# ...

# %%
df_promotion_summary['standard_cases']=((df_promotion_summary['standard_units']/df_promotion_summary['product_units_per_case'])+.49).round(0)
df_promotion_summary['sale_cases']=((df_promotion_summary['sale_units']/df_promotion_summary['product_units_per_case'])+.49).round(0)
        
df_promotion_summary.head()
# Out:
#          promo_id         promo_name price_point retailer_name  \
# 0  Brandega-53999  Spring into Clean           W      Botann's
# 1  Brandega-53999  Spring into Clean           Y      Botann's
# 2  Brandega-53999  Spring into Clean           Z      Botann's
# 3  Brandega-53999  Spring into Clean           V      Botann's
# 4  Brandega-53999  Spring into Clean           X      Botann's
#
#   retailer_store_id product_group_id product_unit_upc product_brand  \
# 0   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 1   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 2   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 3   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 4   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
#
#            product_brand_category_desc      product_unit_description  \
# 0  Dottie's Cleaners All Purpose 10 oz  Dottie's Air Freshener 10 oz
# ...

# %%
df_promotion_summary['PROMOTION_REVENUE_LIFT']=df_promotion_summary['SALE_REVENUE']-df_promotion_summary['STANDARD_REVENUE']
df_promotion_summary['PROMOTION_PROFIT_LIFT']=df_promotion_summary['SALE_PROFIT']-df_promotion_summary['STANDARD_PROFIT']
df_promotion_summary['PROMOTION_UNITS_LIFT']=df_promotion_summary['sale_units']-df_promotion_summary['standard_units']
df_promotion_summary['PROMOTION_CASES_LIFT']=df_promotion_summary['sale_cases']-df_promotion_summary['standard_cases']
df_promotion_summary['PROMOTION_ROI']=100*(df_promotion_summary['PROMOTION_PROFIT_LIFT']/df_promotion_summary['STANDARD_PROFIT'])
df_promotion_summary.head()
# Out:
#          promo_id         promo_name price_point retailer_name  \
# 0  Brandega-53999  Spring into Clean           W      Botann's
# 1  Brandega-53999  Spring into Clean           Y      Botann's
# 2  Brandega-53999  Spring into Clean           Z      Botann's
# 3  Brandega-53999  Spring into Clean           V      Botann's
# 4  Brandega-53999  Spring into Clean           X      Botann's
#
#   retailer_store_id product_group_id product_unit_upc product_brand  \
# 0   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 1   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 2   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 3   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 4   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
#
#            product_brand_category_desc      product_unit_description  \
# 0  Dottie's Cleaners All Purpose 10 oz  Dottie's Air Freshener 10 oz
# ...

# %%
df_promotion_summary.describe()
# Out:
#        product_units_per_case  product_cpg_cogs_price           size  \
# count           189450.000000           189450.000000  189450.000000
# mean                20.788889                4.415889      20.322222
# std                 12.949075                2.094740      25.888967
# min                  3.000000                1.520000      -8.000000
# 25%                 12.000000                3.490000      -8.000000
# 50%                 21.000000                4.085000      16.000000
# 75%                 25.000000                6.190000      28.000000
# max                 40.000000               12.520000      75.000000
#
#                units        p_units     sale_price     sale_units  \
# count  189450.000000  189450.000000  189450.000000  189450.000000
# mean       58.811111     357.278134       5.334559     357.278134
# std        21.259770     887.717419       2.559819     887.717419
# min        15.000000       5.683009       1.469712       5.683009
# ...

# %%
DF_PROMOTION_SUMMARY=df_promotion_summary.rename(str.upper, axis='columns')
DF_PROMOTION_SUMMARY.head()
# Out:
#          PROMO_ID         PROMO_NAME PRICE_POINT RETAILER_NAME  \
# 0  Brandega-53999  Spring into Clean           W      Botann's
# 1  Brandega-53999  Spring into Clean           Y      Botann's
# 2  Brandega-53999  Spring into Clean           Z      Botann's
# 3  Brandega-53999  Spring into Clean           V      Botann's
# 4  Brandega-53999  Spring into Clean           X      Botann's
#
#   RETAILER_STORE_ID PRODUCT_GROUP_ID PRODUCT_UNIT_UPC PRODUCT_BRAND  \
# 0   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 1   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 2   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 3   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 4   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
#
#            PRODUCT_BRAND_CATEGORY_DESC      PRODUCT_UNIT_DESCRIPTION  \
# 0  Dottie's Cleaners All Purpose 10 oz  Dottie's Air Freshener 10 oz
# ...

# %%
xxx=DF_PROMOTION_SUMMARY
xxx=xxx[xxx['PRODUCT'] == 'ICE CREAM']


xxx = xxx.sort_values(['PRODUCT', 'PROMO_ID'])
xxx=xxx[['PROMO_ID',
 'RETAILER_STORE_ID',
 'PRODUCT_GROUP_ID',
 'PRODUCT_UNIT_UPC',
 'PRODUCT',
 'SALE_PRICE','STANDARD_PRICE']]
xxx
# Out:
#              PROMO_ID RETAILER_STORE_ID PRODUCT_GROUP_ID PRODUCT_UNIT_UPC  \
# 37890  Brandega-48335   12345-10024-126    FFF-F-IC-P-64      77220-10116
# 37891  Brandega-48335   12345-10024-126    FFF-F-IC-P-64      77220-10116
# 37892  Brandega-48335   12345-10024-126    FFF-F-IC-P-64      77220-10116
# 37893  Brandega-48335   12345-10024-126    FFF-F-IC-P-64      77220-10116
# 37894  Brandega-48335   12345-10024-126    FFF-F-IC-P-64      77220-10116
# 37895  Brandega-48335   12345-14213-136    FFF-F-IC-P-64      77220-10116
# 37896  Brandega-48335   12345-14213-136    FFF-F-IC-P-64      77220-10116
# 37897  Brandega-48335   12345-14213-136    FFF-F-IC-P-64      77220-10116
# 37898  Brandega-48335   12345-14213-136    FFF-F-IC-P-64      77220-10116
# 37899  Brandega-48335   12345-14213-136    FFF-F-IC-P-64      77220-10116
# 37900  Brandega-48335   12345-14601-157    FFF-F-IC-P-64      77220-10116
# 37901  Brandega-48335   12345-14601-157    FFF-F-IC-P-64      77220-10116
# ...

# %%
# The code was removed by Watson Studio for sharing.

# %%
import ibmdbpy
from ibmdbpy import IdaDataBase
idadbx = idadbx = IdaDataBase(dsn="DASHDB;Database=BLUDB;Hostname=" + credentials_2["host"] + ";PROTOCOL=TCPIP;UID=" + credentials_2["username"] + ";PWD=" + credentials_2["password"])

# %%
idadbx.as_idadataframe(DF_PROMOTION_SUMMARY, "PROMOTION_SUMMARY",clear_existing = True)
# Out:
# DataFrame will be splitted into 854 chunks. (222 rows per chunk)
# Uploaded: 854/854... [DONE]

# %%
from ibmdbpy import IdaDataFrame
df_promotion_summaryx = idadbx.ida_query("SELECT * FROM PROMOTION_SUMMARY")

# %%
df=df_promotion_summaryx

# %%
df.head()
# Out:
#          promo_id         promo_name price_point retailer_name  \
# 0  Brandega-53999  Spring into Clean           W      Botann's
# 1  Brandega-53999  Spring into Clean           Y      Botann's
# 2  Brandega-53999  Spring into Clean           Z      Botann's
# 3  Brandega-53999  Spring into Clean           V      Botann's
# 4  Brandega-53999  Spring into Clean           X      Botann's
#
#   retailer_store_id product_group_id product_unit_upc product_brand  \
# 0   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 1   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 2   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 3   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
# 4   12345-10024-126     D-H-C-AP-10       33488-14010      Dottie's
#
#            product_brand_category_desc      product_unit_description  \
# 0  Dottie's Cleaners All Purpose 10 oz  Dottie's Air Freshener 10 oz
# ...

# %%
df=df.groupby(['promo_id','retailer_store_id','product_unit_upc','price_point','product']).agg({
 'product_units_per_case':'mean',
 'product_cpg_cogs_price':'mean',
 'size':'mean',
 'units':'sum',
 'p_units':'sum',
 'sale_price':'mean',
 'sale_units':'sum',
 'standard_units':'sum',
 'sale_revenue':'sum',
 'sale_cost':'sum',
 'sale_profit':'sum',
 'standard_revenue':'sum',
 'standard_cost':'sum',
 'standard_price':'mean',
 'standard_profit':'sum',
 'standard_cases':'sum',
 'sale_cases':'sum',
 'promotion_revenue_lift':'sum',
 'promotion_profit_lift':'sum',
 'promotion_units_lift':'sum',
 'promotion_cases_lift':'sum',
 'promotion_roi':'mean'})

# %%
df.reset_index(level=0, inplace=True)
df.reset_index(level=0, inplace=True)
df.reset_index(level=0, inplace=True)
df.reset_index(level=0, inplace=True)
df.reset_index(level=0, inplace=True)
df
# Out:
#           product price_point product_unit_upc retailer_store_id  \
# 0       TRAIL_MIX           V      44309-79016   12345-10024-126
# 1       TRAIL_MIX           W      44309-79016   12345-10024-126
# 2       TRAIL_MIX           X      44309-79016   12345-10024-126
# 3       TRAIL_MIX           Y      44309-79016   12345-10024-126
# 4       TRAIL_MIX           Z      44309-79016   12345-10024-126
# 5       TRAIL_MIX           V      44309-79116   12345-10024-126
# 6       TRAIL_MIX           W      44309-79116   12345-10024-126
# 7       TRAIL_MIX           X      44309-79116   12345-10024-126
# 8       TRAIL_MIX           Y      44309-79116   12345-10024-126
# 9       TRAIL_MIX           Z      44309-79116   12345-10024-126
# 10      TRAIL_MIX           V      44309-79216   12345-10024-126
# 11      TRAIL_MIX           W      44309-79216   12345-10024-126
# 12      TRAIL_MIX           X      44309-79216   12345-10024-126
# ...

# %%
df = df[['promo_id','product','size','price_point',
 'units',
 'p_units',
 'sale_price',
 'sale_units',
 'standard_price',
 'standard_units',
 'sale_revenue',
 'sale_cost',
 'sale_profit',
 'standard_revenue',
 'standard_cost',
 'standard_profit',
 'standard_cases',
 'sale_cases',
 'promotion_revenue_lift',
 'promotion_profit_lift',
 'promotion_units_lift',
 'promotion_cases_lift',
 'promotion_roi']]

# %%
DF=df.rename(str.upper, axis='columns')

# %%
DF
# Out:
#               PROMO_ID    PRODUCT  SIZE PRICE_POINT  UNITS    P_UNITS  \
# 0       Brandega-21621  TRAIL_MIX  16.0           V   50.0  55.588752
# 1       Brandega-21621  TRAIL_MIX  16.0           W   50.0  64.426520
# 2       Brandega-21621  TRAIL_MIX  16.0           X   50.0  51.169868
# 3       Brandega-21621  TRAIL_MIX  16.0           Y   50.0  60.007636
# 4       Brandega-21621  TRAIL_MIX  16.0           Z   50.0  68.845404
# 5       Brandega-21621  TRAIL_MIX  16.0           V   50.0  55.389334
# 6       Brandega-21621  TRAIL_MIX  16.0           W   50.0  64.236585
# 7       Brandega-21621  TRAIL_MIX  16.0           X   50.0  50.965708
# 8       Brandega-21621  TRAIL_MIX  16.0           Y   50.0  59.812959
# 9       Brandega-21621  TRAIL_MIX  16.0           Z   50.0  68.660210
# 10      Brandega-21621  TRAIL_MIX  16.0           V   50.0  43.823090
# 11      Brandega-21621  TRAIL_MIX  16.0           W   50.0  53.220331
# ...

# %%
idadbx.as_idadataframe(DF, "PROMO_ID_PRODUCT_PROMOTION_SUMMARY",clear_existing = True)
# Out:
# DataFrame will be splitted into 546 chunks. (347 rows per chunk)
# Uploaded: 546/546... [DONE]

# %%
df.describe()
# Out:
#                 size          units        p_units     sale_price  \
# count  189450.000000  189450.000000  189450.000000  189450.000000
# mean       20.322222      58.811111     357.278134       5.334559
# std        25.888967      21.259770     887.717419       2.559819
# min        -8.000000      15.000000       5.683009       1.469712
# 25%        -8.000000      50.000000      41.574381       3.688608
# 50%        16.000000      72.000000      69.170720       4.786320
# 75%        28.000000      72.000000      93.995538       7.056504
# max        75.000000      80.000000    3345.395272      17.830120
#
#           sale_units  standard_price  standard_units   sale_revenue  \
# count  189450.000000   189450.000000   189450.000000  189450.000000
# mean      357.278134        6.284667       28.422222    2160.967815
# std       887.717419        1.142339       10.369832    5879.670998
# min         5.683009        4.610000        6.000000      32.505569
# ...

# %%
df=df_promotion_summaryx

# %%
df=df.groupby(['promo_id','price_point']).agg({
 'product_units_per_case':'mean',
 'product_cpg_cogs_price':'mean',
 'size':'mean',
 'units':'sum',
 'p_units':'sum',
 'sale_price':'mean',
 'sale_units':'sum',
 'standard_price':'mean',
 'standard_units':'sum',
 'sale_revenue':'sum',
 'sale_cost':'sum',
 'sale_profit':'sum',
 'standard_revenue':'sum',
 'standard_cost':'sum',
 'standard_profit':'sum',
 'standard_cases':'sum',
 'sale_cases':'sum',
 'promotion_revenue_lift':'sum',
 'promotion_profit_lift':'sum',
 'promotion_units_lift':'sum',
 'promotion_cases_lift':'sum',
 'promotion_roi':'mean'})

# %%
df.reset_index(level=0, inplace=True)
df.reset_index(level=0, inplace=True)
df.head(10)
# Out:
#   price_point        promo_id  size       p_units  sale_price  standard_cost  \
# 0           V  Brandega-21621   4.0  1.094940e+06    6.085485     2726269.70
# 1           W  Brandega-21621   4.0  1.232329e+06    5.444907     2726269.70
# 2           X  Brandega-21621   4.0  1.026246e+06    6.405773     2726269.70
# 3           Y  Brandega-21621   4.0  1.163635e+06    5.765196     2726269.70
# 4           Z  Brandega-21621   4.0  1.301023e+06    5.124619     2726269.70
# 5           V  Brandega-48335  40.0  2.039949e+07    4.895479     1196364.12
# 6           W  Brandega-48335  40.0  1.982382e+07    4.487522     1196364.12
# 7           X  Brandega-48335  40.0  1.107640e+06    4.079566     1196364.12
# 8           Y  Brandega-48335  40.0  1.867249e+07    3.671609     1196364.12
# 9           Z  Brandega-48335  40.0  1.107640e+06    3.263652     1196364.12
#
#    promotion_cases_lift  sale_revenue  standard_cases    sale_units  \
# ...

# %%
df.loc[((df['promo_id'] == 'Brandega-48335') & (df['price_point']=='W')), 'sale_cases'] = 124566
df.loc[((df['promo_id'] == 'Brandega-48335') & (df['price_point']=='V')), 'sale_cases'] = 99875
df.loc[((df['promo_id'] == 'Brandega-48335') & (df['price_point']=='Y')), 'sale_cases'] = 198802
df.loc[((df['promo_id'] == 'Brandega-48335') & (df['price_point']=='Z')), 'sale_cases'] = 287636

# %%
df = df[['promo_id','price_point','sale_cases','standard_cases','product_units_per_case','product_cpg_cogs_price','standard_price','sale_price']]

# %%
df['standard_cases']=df['standard_cases']*0.39332714
df['sale_cases']=df['sale_cases']*0.39332714
df['TPP_DISCOUNT']=(df['standard_price']-df['sale_price'])/df['standard_price']
df['INCREMENTAL_CASES']=df['sale_cases']-df['standard_cases']

# %%
df['sale_units']=df['sale_cases']*df['product_units_per_case']
df['standard_units']=df['standard_cases']*df['product_units_per_case']
df['sale_revenue']=df['sale_units']*df['sale_price']
df['standard_revenue']=df['standard_units']*df['standard_price']
df['sale_cost']=df['sale_units']*df['product_cpg_cogs_price']
df['standard_cost']=df['standard_units']*df['product_cpg_cogs_price']
df['sale_profit']=df['sale_revenue']-df['sale_cost']
df['standard_profit']=df['standard_revenue']-df['standard_cost']

# %%
df['incremental_profit']=df['sale_profit']-df['standard_profit']
df['incremental_revenue']=df['sale_revenue']-df['standard_revenue']

df
# Out:
#           promo_id price_point     sale_cases  standard_cases  \
# 0   Brandega-21621           V   16000.941382     7285.991941
# 1   Brandega-21621           W   18596.113852     7285.991941
# 2   Brandega-21621           X   15325.992010     7285.991941
# 3   Brandega-21621           Y   17137.656817     7285.991941
# 4   Brandega-21621           Z   19878.360328     7285.991941
# 5   Brandega-48335           V   39283.548107    18546.161305
# 6   Brandega-48335           W   48995.188521    18546.161305
# 7   Brandega-48335           X   59098.189439    18546.161305
# 8   Brandega-48335           Y   78194.222086    18546.161305
# 9   Brandega-48335           Z  113135.045241    18546.161305
# 10  Brandega-53999           V    8559.978548     3642.995971
# 11  Brandega-53999           W    8898.633215     3642.995971
# 12  Brandega-53999           X    8383.767989     3642.995971
# 13  Brandega-53999           Y    8718.882712     3642.995971
# ...

# %%
df = df[['promo_id','price_point','TPP_DISCOUNT','INCREMENTAL_CASES',
 'incremental_revenue','incremental_profit']]

# %%
DF=df.rename(str.upper, axis='columns')
DF
# Out:
#           PROMO_ID PRICE_POINT  TPP_DISCOUNT  INCREMENTAL_CASES  \
# 0   Brandega-21621           V      0.116766        8714.949441
# 1   Brandega-21621           W      0.209738       11310.121911
# 2   Brandega-21621           X      0.070280        8040.000069
# 3   Brandega-21621           Y      0.163252        9851.664876
# 4   Brandega-21621           Z      0.256224       12592.368387
# 5   Brandega-48335           V     -0.061926       20737.386802
# 6   Brandega-48335           W      0.026568       30449.027216
# 7   Brandega-48335           X      0.115062       40552.028134
# 8   Brandega-48335           Y      0.203556       59648.060781
# 9   Brandega-48335           Z      0.292049       94588.883936
# 10  Brandega-53999           V      0.111951        4916.982577
# 11  Brandega-53999           W      0.205430        5255.637245
# 12  Brandega-53999           X      0.065211        4740.772018
# 13  Brandega-53999           Y      0.158690        5075.886742
# ...

# %%
idadbx.as_idadataframe(DF, "PROMO_ID_PROMOTION_SUMMARY",clear_existing = True)
# Out:
# Uploading 15 rows (maxnrow was set to 1333)

# %%
xxx = idadbx.ida_query("SELECT * FROM PROMO_ID_PROMOTION_SUMMARY")

# %%
xxx
# Out:
#           promo_id price_point  tpp_discount  incremental_cases  \
# 0   Brandega-21621           V      0.116766        8714.949441
# 1   Brandega-21621           W      0.209738       11310.121911
# 2   Brandega-21621           X      0.070280        8040.000069
# 3   Brandega-21621           Y      0.163252        9851.664876
# 4   Brandega-21621           Z      0.256224       12592.368387
# 5   Brandega-48335           V     -0.061926       20737.386802
# 6   Brandega-48335           W      0.026568       30449.027216
# 7   Brandega-48335           X      0.115062       40552.028134
# 8   Brandega-48335           Y      0.203556       59648.060781
# 9   Brandega-48335           Z      0.292049       94588.883936
# 10  Brandega-53999           V      0.111951        4916.982577
# 11  Brandega-53999           W      0.205430        5255.637245
# 12  Brandega-53999           X      0.065211        4740.772018
# 13  Brandega-53999           Y      0.158690        5075.886742
# ...
